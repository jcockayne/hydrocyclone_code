# %%
import pandas as pd
import os
import numpy as np

# %%
all_results = np.array([f for f in os.listdir('results') if f[0] != '.'])
order = np.argsort([os.path.getmtime(os.path.join('results', path)) for path in all_results])
print all_results[order[::-1]]
# Out:
# ['temporal_recovery_n=6_collocation_1ea6e25d'
#  'temporal_recovery_n=4_ff23183b'
#  'temporal_recovery_n=6_collocation_06a5bfcc'
#  'temporal_recovery_n=5_collocation_3f941335'
#  'temporal_recovery_n=4_collocation_7ae4c854'
#  'temporal_recovery_n=6_collocation_ef8f8d1f'
#  'temporal_recovery_n=4_collocation_7e29f7d8'
#  'temporal_recovery_n=6_bebc881d' 'temporal_recovery_n=3_5b4a65a4'
#  'static_recovery_f14_n=7' 'static_recovery_f14_n=7_collocation'
#  'static_recovery_f14_n=2' 'static_recovery_f14_n=2_collocation'
#  'temporal_recovery_n=5_28e243ba' 'temporal_recovery_n=5_aab75251'
#  'temporal_recovery_n=5_5b47c487' 'static_recovery_f14_n=6'
#  'static_recovery_f14_n=6_collocation' 'static_recovery_f14_n=5'
#  'static_recovery_f14_n=5_collocation'
#  'static_recovery_f14_n=4_collocation' 'static_recovery_f14_n=4'
#  'static_recovery_f14_n=3' 'static_recovery_f14_n=3_collocation']

# %%
result_path = os.path.join('results', all_results[order][-1])

# %%
tmp = pd.read_csv(os.path.join(result_path, 'summary.csv'), index_col=0)
tmp[~tmp.Kernel_Name.isnull()].iloc[::-1]
# Out:
#                 Kernel_Name      Beta    Accept         ESS       Time
# 799                Frame_18  0.020023  0.330340  161.488476  56.942577
# 798  Frame_17->18_temp=0.99  0.020023  0.329825  173.145625  57.216463
# 797  Frame_17->18_temp=0.98  0.020023  0.329040  182.063260  57.021074
# 796  Frame_17->18_temp=0.97  0.020023  0.336265   98.324210  57.123829
# 795  Frame_17->18_temp=0.96  0.020023  0.337205  102.416523  57.032583
# 794  Frame_17->18_temp=0.95  0.020023  0.336995  117.246370  57.112742
# 793  Frame_17->18_temp=0.94  0.020023  0.337755  130.163556  57.277650
# 792  Frame_17->18_temp=0.93  0.020023  0.338790  144.020454  57.156979
# 791  Frame_17->18_temp=0.92  0.020023  0.340545  161.011700  57.243891
# 790  Frame_17->18_temp=0.91  0.020023  0.341175  175.883696  57.292670
# 789   Frame_17->18_temp=0.9  0.020023  0.336140  187.595974  57.301545
# 788  Frame_17->18_temp=0.89  0.020023  0.330730   95.785211  57.346396
# 787  Frame_17->18_temp=0.88  0.020023  0.332365  107.938896  57.132940
# 786  Frame_17->18_temp=0.87  0.020023  0.332760  105.802941  57.156069
# 785  Frame_17->18_temp=0.86  0.020023  0.332500  113.470241  57.280267
# 784  Frame_17->18_temp=0.85  0.020023  0.328525  119.477559  57.281539
# 783  Frame_17->18_temp=0.84  0.020023  0.332240  125.936007  57.332156
# 782  Frame_17->18_temp=0.83  0.020023  0.333645  135.077243  57.148886
# 781  Frame_17->18_temp=0.82  0.020023  0.332330  141.910087  57.140003
# 780  Frame_17->18_temp=0.81  0.020023  0.330360  159.809098  57.291963
# 779   Frame_17->18_temp=0.8  0.020023  0.327265  172.425725  57.277755
# 778  Frame_17->18_temp=0.79  0.020023  0.326325  184.575292  57.563640
# 777  Frame_17->18_temp=0.78  0.020023  0.341420   90.469879  57.148394
# 776  Frame_17->18_temp=0.77  0.020023  0.339540  115.114921  59.132881
# 775  Frame_17->18_temp=0.76  0.020023  0.341055  113.731366  57.166147
# 774  Frame_17->18_temp=0.75  0.020023  0.341005  126.550980  57.021994
# 773  Frame_17->18_temp=0.74  0.020023  0.338145  132.220059  57.561150
# 772  Frame_17->18_temp=0.73  0.020023  0.337835  148.260911  57.245905
# 771  Frame_17->18_temp=0.72  0.020023  0.339075  159.120373  57.069380
# 770  Frame_17->18_temp=0.71  0.020023  0.340910  170.140389  57.332118
# ..                      ...       ...       ...         ...        ...
# 29    Frame_10->11_temp=0.3  0.035596  0.242025  111.471107  60.459626
# 28   Frame_10->11_temp=0.29  0.035596  0.248210  113.130358  60.276099
# 27   Frame_10->11_temp=0.28  0.035596  0.254295  112.185445  60.960300
# 26   Frame_10->11_temp=0.27  0.035596  0.259470  111.816509  60.472855
# 25   Frame_10->11_temp=0.26  0.035596  0.265110  111.667611  60.554920
# 24   Frame_10->11_temp=0.25  0.035596  0.268240  112.303856  60.528777
# 23   Frame_10->11_temp=0.24  0.035596  0.277835  116.687982  60.388116
# 22   Frame_10->11_temp=0.23  0.035596  0.282500  117.712532  61.009130
# 21   Frame_10->11_temp=0.22  0.035596  0.288765  117.890565  60.374855
# 20   Frame_10->11_temp=0.21  0.035596  0.198100  121.200420  60.314671
# 19    Frame_10->11_temp=0.2  0.047461  0.205155  123.492552  60.062468
# 18   Frame_10->11_temp=0.19  0.047461  0.210455  128.281495  59.479507
# 17   Frame_10->11_temp=0.18  0.047461  0.216160  132.015131  59.390528
# 16   Frame_10->11_temp=0.17  0.047461  0.218815  135.116436  59.402308
# 15   Frame_10->11_temp=0.16  0.047461  0.228820  137.886004  59.714173
# 14   Frame_10->11_temp=0.15  0.047461  0.236810  144.494775  59.749663
# 13   Frame_10->11_temp=0.14  0.047461  0.244130  151.911567  59.783895
# 12   Frame_10->11_temp=0.13  0.047461  0.258270  157.473240  62.930750
# 11   Frame_10->11_temp=0.12  0.047461  0.270325  163.320773  64.843761
# 10   Frame_10->11_temp=0.11  0.047461  0.278380  171.191844  61.717140
# 9     Frame_10->11_temp=0.1  0.047461  0.191240  183.684516  65.843056
# 8    Frame_10->11_temp=0.09  0.063281  0.201905   98.278291  67.565332
# 7    Frame_10->11_temp=0.08  0.063281  0.221395  111.520451  62.244970
# 6    Frame_10->11_temp=0.07  0.063281  0.240590  133.909803  64.987555
# 5    Frame_10->11_temp=0.06  0.063281  0.258975  169.627181  66.674192
# 4    Frame_10->11_temp=0.05  0.063281  0.177090   95.499018  65.904985
# 3    Frame_10->11_temp=0.04  0.084375  0.209440  129.804915  60.720188
# 2    Frame_10->11_temp=0.03  0.084375  0.147470   91.412918  59.759541
# 1    Frame_10->11_temp=0.02  0.112500  0.116720   58.583775  62.254597
# 0    Frame_10->11_temp=0.01  0.150000  0.138355   34.333964  58.738429
#
# [800 rows x 5 columns]
