# %%
import pandas as pd
import os
import numpy as np

# %%
all_results = np.array([f for f in os.listdir('results') if f[0] != '.'])
order = np.argsort([os.path.getmtime(os.path.join('results', path)) for path in all_results])
print(all_results[order[::-1]])
# Out:
# ['temporal_recovery_n=6_collocation_41d30aa0' 'static_recovery_f11_n=7']

# %%
result_path = os.path.join('results', all_results[order][-1])

# %%
tmp = pd.read_csv(os.path.join(result_path, 'summary.csv'), index_col=0)
tmp[~tmp.Kernel_Name.isnull()].iloc[::-1]
# Out:
#                                  Kernel_Name      Beta  Accept         ESS  \
# 7583                 Frame_17->18_temp=0.584  0.011263   0.480  168.036819
# 7582                 Frame_17->18_temp=0.583  0.011263   0.585  169.525986
# 7581                 Frame_17->18_temp=0.582  0.011263   0.545  171.041789
# 7580                 Frame_17->18_temp=0.581  0.011263   0.530  172.365330
# 7579                  Frame_17->18_temp=0.58  0.011263   0.540  173.186013
# 7578                 Frame_17->18_temp=0.579  0.011263   0.450  174.178395
# 7577                 Frame_17->18_temp=0.578  0.011263   0.520  175.218568
# 7576                 Frame_17->18_temp=0.577  0.011263   0.565  176.226548
# 7575    Frame_17->18_temp=0.5760000000000001  0.011263   0.510  177.273253
# 7574    Frame_17->18_temp=0.5750000000000001  0.011263   0.565  178.605330
# 7573    Frame_17->18_temp=0.5740000000000001  0.011263   0.550  179.955500
# 7572    Frame_17->18_temp=0.5730000000000001  0.011263   0.540  181.544979
# 7571    Frame_17->18_temp=0.5720000000000001  0.011263   0.530  183.377885
# 7570    Frame_17->18_temp=0.5710000000000001  0.011263   0.545  185.383888
# 7569    Frame_17->18_temp=0.5700000000000001  0.011263   0.515  187.183914
# 7568    Frame_17->18_temp=0.5690000000000001  0.011263   0.475  188.973853
# 7567    Frame_17->18_temp=0.5680000000000001  0.011263   0.530  190.513282
# 7566    Frame_17->18_temp=0.5670000000000001  0.011263   0.510  191.887198
# 7565    Frame_17->18_temp=0.5660000000000001  0.011263   0.560  193.097944
# 7564    Frame_17->18_temp=0.5650000000000001  0.011263   0.510  194.440048
# 7563    Frame_17->18_temp=0.5640000000000001  0.011263   0.545  195.496514
# 7562    Frame_17->18_temp=0.5630000000000001  0.011263   0.540  196.478312
# 7561                 Frame_17->18_temp=0.562  0.011263   0.530  197.510923
# 7560                 Frame_17->18_temp=0.561  0.011263   0.570  198.470851
# 7559                  Frame_17->18_temp=0.56  0.011263   0.570  199.246599
# 7558                 Frame_17->18_temp=0.559  0.011263   0.550  199.786888
# 7557                 Frame_17->18_temp=0.558  0.011263   0.555   99.566706
# 7556                 Frame_17->18_temp=0.557  0.011263   0.560  103.122864
# 7555                 Frame_17->18_temp=0.556  0.011263   0.510  106.231905
# 7554                 Frame_17->18_temp=0.555  0.011263   0.490  109.064010
# ...                                      ...       ...     ...         ...
# 29                    Frame_10->11_temp=0.03  0.063281   0.340  121.825707
# 28                   Frame_10->11_temp=0.029  0.063281   0.300  142.439954
# 27                   Frame_10->11_temp=0.028  0.063281   0.295  162.144408
# 26                   Frame_10->11_temp=0.027  0.063281   0.285  180.137436
# 25    Frame_10->11_temp=0.026000000000000002  0.063281   0.300  193.918775
# 24                   Frame_10->11_temp=0.025  0.063281   0.300   85.596514
# 23                   Frame_10->11_temp=0.024  0.063281   0.195  108.115030
# 22                   Frame_10->11_temp=0.023  0.084375   0.260  135.287636
# 21                   Frame_10->11_temp=0.022  0.084375   0.225  165.147664
# 20                   Frame_10->11_temp=0.021  0.084375   0.220  189.958401
# 19                    Frame_10->11_temp=0.02  0.084375   0.255   82.169170
# 18                   Frame_10->11_temp=0.019  0.084375   0.270  116.421620
# 17    Frame_10->11_temp=0.018000000000000002  0.084375   0.305  152.308150
# 16                   Frame_10->11_temp=0.017  0.084375   0.195  184.439457
# 15                   Frame_10->11_temp=0.016  0.112500   0.230   84.419374
# 14                   Frame_10->11_temp=0.015  0.112500   0.235  122.272616
# 13                   Frame_10->11_temp=0.014  0.112500   0.245  170.142101
# 12    Frame_10->11_temp=0.013000000000000001  0.112500   0.225   85.281652
# 11                   Frame_10->11_temp=0.012  0.112500   0.275  152.710739
# 10                   Frame_10->11_temp=0.011  0.112500   0.190   61.667632
# 9                     Frame_10->11_temp=0.01  0.150000   0.285  139.708996
# 8     Frame_10->11_temp=0.009000000000000001  0.150000   0.250   57.165964
# 7                    Frame_10->11_temp=0.008  0.150000   0.225  125.711837
# 6                    Frame_10->11_temp=0.007  0.150000   0.120   53.631160
# 5                    Frame_10->11_temp=0.006  0.200000   0.225   40.907423
# 4                    Frame_10->11_temp=0.005  0.200000   0.260   42.930604
# 3                    Frame_10->11_temp=0.004  0.200000   0.250   14.325778
# 2                    Frame_10->11_temp=0.003  0.200000   0.250    1.009434
# 1                    Frame_10->11_temp=0.002  0.200000   0.360    1.190266
# 0                    Frame_10->11_temp=0.001  0.200000   0.490    1.000005
#
#           Time
# 7583  0.121021
# 7582  0.116822
# 7581  0.121919
# 7580  0.112353
# 7579  0.118936
# 7578  0.113307
# 7577  0.200281
# 7576  0.151092
# 7575  0.155893
# 7574  0.115169
# 7573  0.112871
# 7572  0.119996
# 7571  0.128587
# 7570  0.116422
# 7569  0.111238
# 7568  0.111745
# 7567  0.114572
# 7566  0.111886
# 7565  0.116575
# 7564  0.163281
# 7563  0.145959
# 7562  0.139761
# 7561  0.147834
# 7560  0.150306
# 7559  0.145057
# 7558  0.133954
# 7557  0.155645
# 7556  0.151051
# 7555  0.125369
# 7554  0.117851
# ...        ...
# 29    0.110466
# 28    0.120256
# 27    0.126297
# 26    0.111493
# 25    0.117301
# 24    0.115400
# 23    0.123439
# 22    0.117525
# 21    0.125810
# 20    0.105331
# 19    0.116968
# 18    0.110780
# 17    0.106027
# 16    0.118269
# 15    0.150228
# 14    0.134194
# 13    0.118398
# 12    0.107048
# 11    0.110252
# 10    0.111994
# 9     0.115559
# 8     0.128040
# 7     0.167762
# 6     0.156618
# 5     0.106617
# 4     0.106886
# 3     0.112077
# 2     0.110564
# 1     0.114788
# 0     0.142188
#
# [7584 rows x 5 columns]
